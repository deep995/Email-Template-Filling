# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv
import spacy
import pandas as pd

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Define the template filling functions

def fill_buy_template(doc):
    # Template filling logic for BUY template
    buyer = ""
    item = ""
    price = ""
    quantity = ""
    source = ""

    for token in doc:
        if token.ent_type_ == "PERSON" or token.ent_type_ == "ORG":
            if buyer == "":
                buyer = token.text
        elif token.ent_type_ == "PRODUCT" or token.ent_type_ == "ORG":
            if item == "":
                item = token.text
        elif token.text.startswith("$"):
            if price == "":
                price = token.text[1:] # Remove the dollar sign
            break

    filled_template = f"BUY({buyer}, {item}, {price}, {quantity}, {source})"
    return filled_template

def fill_work_template(doc):
    # Template filling logic for WORK template
    person = ""
    organization = ""
    position = ""
    location = ""

    for token in doc:
        if token.ent_type_ == "PERSON":
            if person == "":
                person = token.text
            break

    filled_template = f"WORK({person}, {organization}, {position}, {location})"
    return filled_template

def fill_part_template(doc):
    # Template filling logic for PART template
    location_1 = ""
    location_2 = ""

    for token in doc:
        if token.ent_type_ == "LOC" or token.ent_type_ == "GPE" or token.ent_type_ == "NORP" or token.ent_type_ == "FAC":
            if location_1 == "":
                location_1 = token.text
            elif location_2 == "":
                location_2 = token.text

    filled_template = f"PART({location_1}, {location_2})"
    return filled_template
# Define the template names and their respective filling functions
templates = {
    "BUY": fill_buy_template,
    "WORK": fill_work_template,
    "PART": fill_part_template
}

# %%
# Define the input CSV file path
csv_file = "/content/drive/MyDrive/Colab Notebooks/labeled_emails.csv"


# Open the CSV file and read the email texts
with open(csv_file, "r", newline="") as file:
    reader = csv.DictReader(file)
    for row in reader:
        email_text = row["email"]

        # Process the email text using spaCy
        doc = nlp(email_text)
        
        # Iterate over the detected entities in the document
        for ent in doc.ents:
          # If the entity label matches a template, fill the template
          if ent.label_ == 'PRODUCT':
            filled_template = templates['BUY'](doc)
            print(f"Template: {template_name}")
            print(f"Filled Template: {filled_template}")
          if ent.label_ == 'ORG':
            filled_template = templates['WORK'](doc)
            print(f"Template: {template_name}")
            print(f"Filled Template: {filled_template}")
          if ent.label_ in ["LOC","GPE","NORP","FAC"]:
            filled_template = templates['PART'](doc)
            print(f"Template: {template_name}")
            print(f"Filled Template: {filled_template}")
          print()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(adsl, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(adsl, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(adsl, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(axantil, , , )
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(axantil, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(axantil, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(srvl, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(ab, .)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(aol, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: BUY(aol, 9603, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(nagasaki, )
#
# Template: CARDINAL
# Filled Template: WORK(aol, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(aol, , , )
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(aol, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(aol, 9603, , , )
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(aol, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: BUY(aol, mailin, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(aol, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(aol, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(aol, mailin, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(aol, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(mxo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(org, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(startlogic, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(startlogic, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(startlogic, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(chaque, , , )
#
# Template: CARDINAL
# Filled Template: WORK(chaque, , , )
#
# Template: CARDINAL
# Filled Template: WORK(chaque, , , )
#
# Template: CARDINAL
# Filled Template: PART(dans, )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(uk, )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(kyoto, )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(unl, , , )
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(unl, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(unl, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(unl, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(kumin, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(kumin, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(kumin, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(ibrkntol, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(adsl, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(adsl, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(adsl, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(diese, diese)
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(diese, diese)
#
# Template: CARDINAL
# Filled Template: PART(diese, diese)
#
# Template: CARDINAL
# Filled Template: BUY(rechtlich, das, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(markenweine, , , )
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(neoplus, )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(markenweine, , , )
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(markenweine, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(info, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(diese, )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(ian, uk)
#
#
#
# Template: CARDINAL
# Filled Template: PART(ian, uk)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(ian, uk)
#
# Template: CARDINAL
# Filled Template: PART(ian, uk)
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(uk, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(ian, uk)
#
# Template: CARDINAL
# Filled Template: WORK(uk, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(uk, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(uk, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(gerd, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(pll, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(english, )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(destinatari, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(destinatari, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(unbeiivabie, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(unbeiivabie, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(org, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(nagasaki, )
#
# Template: CARDINAL
# Filled Template: WORK(br, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(br, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(br, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(br, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carpenter, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carpenter, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(carpenter, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(br, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(br, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(clamdscan, neoplus)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(clamdscan, neoplus)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(br, , , )
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(br, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(baco, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(stngvaol, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(stngvaol, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(stngvaol, , , )
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(stngvaol, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(stngvaol, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(antonio, , , )
#
# Template: CARDINAL
# Filled Template: WORK(antonio, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(antonio, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: BUY(info, babbitt, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
# Template: CARDINAL
# Filled Template: PART(p, .)
#
#
# Template: CARDINAL
# Filled Template: PART(p, .)
#
#
# Template: CARDINAL
# Filled Template: PART(p, .)
#
#
# Template: CARDINAL
# Filled Template: PART(p, .)
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(st, .)
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(namelijk, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(leveren, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(seattle, )
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: PART(altadena, california)
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(carl, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(info, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
# Template: CARDINAL
# Filled Template: PART(p, .)
#
#
# Template: CARDINAL
# Filled Template: PART(p, .)
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(getmethru, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(helo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: BUY(helo, squirrelmail, , , )
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: PART(the, united)
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(groomsman, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(american, )
#
#
# Template: CARDINAL
# Filled Template: PART(il, highbadcholesterin)
#
# Template: CARDINAL
# Filled Template: PART(il, highbadcholesterin)
#
#
# Template: CARDINAL
# Filled Template: PART(il, highbadcholesterin)
#
# Template: CARDINAL
# Filled Template: PART(il, highbadcholesterin)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(don, , , )
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(al, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(la, velocidad)
#
# Template: CARDINAL
# Filled Template: PART(la, velocidad)
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(la, velocidad)
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(al, , , )
#
# Template: CARDINAL
# Filled Template: PART(la, velocidad)
#
#
# Template: CARDINAL
# Filled Template: WORK(al, , , )
#
# Template: CARDINAL
# Filled Template: PART(la, velocidad)
#
#
#
# Template: CARDINAL
# Filled Template: PART(la, velocidad)
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(daniel, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(michael, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(china, china)
#
# Template: CARDINAL
# Filled Template: PART(china, china)
#
# Template: CARDINAL
# Filled Template: PART(china, china)
#
#
# Template: CARDINAL
# Filled Template: WORK(guangdong, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(guangdong, , , )
#
# Template: CARDINAL
# Filled Template: PART(china, china)
#
# Template: CARDINAL
# Filled Template: PART(china, china)
#
# Template: CARDINAL
# Filled Template: WORK(guangdong, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(guangdong, , , )
#
# Template: CARDINAL
# Filled Template: PART(china, china)
#
# Template: CARDINAL
# Filled Template: PART(china, china)
#
#
# Template: CARDINAL
# Filled Template: PART(china, china)
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(guangdong, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(guangdong, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(guangdong, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(guangdong, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(niet, , , )
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: BUY(, tetris, , , )
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(us, los)
#
#
# Template: CARDINAL
# Filled Template: PART(us, los)
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(us, los)
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(sh, )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(mary, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(london, england)
#
# Template: CARDINAL
# Filled Template: PART(london, england)
#
#
# Template: CARDINAL
# Filled Template: PART(london, england)
#
# Template: CARDINAL
# Filled Template: PART(london, england)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(adeyinka, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(london, bonn)
#
#
#
# Template: CARDINAL
# Filled Template: PART(london, bonn)
#
# Template: CARDINAL
# Filled Template: PART(london, bonn)
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(db, )
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(heatt, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(phoenix, )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(nigerian, nigerian)
#
# Template: CARDINAL
# Filled Template: PART(nigerian, nigerian)
#
#
# Template: CARDINAL
# Filled Template: PART(nigerian, nigerian)
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(bloomberg, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(bloomberg, , , )
#
# Template: CARDINAL
# Filled Template: PART(asia, p)
#
#
# Template: CARDINAL
# Filled Template: PART(asia, p)
#
#
# Template: CARDINAL
# Filled Template: WORK(bloomberg, , , )
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(bloomberg, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(bloomberg, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(bloomberg, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(el, gran)
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(el, gran)
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
# Template: CARDINAL
# Filled Template: PART(el, gran)
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
# Template: CARDINAL
# Filled Template: PART(el, gran)
#
#
#
# Template: CARDINAL
# Filled Template: BUY(\, queremos, , , )
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(el, gran)
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(\, , , )
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(obese, russian)
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(obese, russian)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(geo, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(wor, , , )
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(wor, , , )
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(wor, , , )
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(wor, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(wor, , , )
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(geo, , , )
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(geo, , , )
#
#
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
# Template: CARDINAL
# Filled Template: PART(german, french)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
# Template: CARDINAL
# Filled Template: PART(french, spanish)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Template: CARDINAL
# Filled Template: WORK(, , , )
